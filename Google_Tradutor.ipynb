# %% [markdown]
# <a href="https://colab.research.google.com/github/nilvanfelipe/.projeto-10_oo-saborexpress/blob/main/Google_Tradutor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install googletrans==4.0.0-rc1
